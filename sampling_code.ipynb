# %%
import os
import json
import random

# Path to the zero-shot directory
# folder_path = "zero-shot"
folder_path = "few-shot"
sample_size = 20

# Loop over each JSON file in the folder
for filename in os.listdir(folder_path):
    if filename.endswith(".json") and not filename.endswith("_sample.json"):
        file_path = os.path.join(folder_path, filename)

        # Read the JSON data
        with open(file_path, "r") as f:
            data = json.load(f)

        # Sample 20 elements (or fewer if not enough data)
        sample = random.sample(data, min(sample_size, len(data)))

        # Save to a new file
        sample_file_path = os.path.join(folder_path, filename.replace(".json", "_sample.json"))
        with open(sample_file_path, "w") as f:
            json.dump(sample, f, indent=2)

        print(f"Saved sample to {sample_file_path}")
# Out:
# Saved sample to few-shot/type_train_multimodal_few_shot_2ex_sample.json
# Saved sample to few-shot/subtype_train_multimodal_few_shot_1ex_sample.json
# Saved sample to few-shot/subtype_test_multimodal_few_shot_1ex_sample.json
# Saved sample to few-shot/type_test_multimodal_few_shot_2ex_sample.json

# %%
import pandas as pd

# %%
sample_size = 20

# %%
df_sample = all_df.sample(n=min(sample_size, len(all_df)), random_state=42)

# %%
sample_filename = "./all_sample.csv"

# %%
df_sample.to_csv("./all_sample.csv")

# %%
all_df.columns
# Out:
# Index(['video_id', 'Input.video_url_vimeo', 'Input.video_id',
#        'Input.video_description', 'title', 'video_url_vimeo',
#        'video_timestamp', 'video_duration', 'video_locationcreated',
#        'video_diggcount', 'video_sharecount', 'video_commentcount',
#        'video_playcount', 'video_description', 'video_is_ad', 'video_stickers',
#        'author_username', 'author_name', 'author_followercount',
#        'author_followingcount', 'author_heartcount', 'author_videocount',
#        'author_diggcount', 'author_verified', 'primary', 'secondary',
#        'src_path', 'video_url_tiktok', 'type', 'subtype', 'severity',
#        'HITId_A', 'HITId_B', 'AssignmentId_A', 'AssignmentId_B', 'WorkerId_A',
#        'WorkerId_B', 'SubmitTime_A', 'SubmitTime_B', 'note_A', 'note_B',
#        'severity_A', 'severity_B', 'body_A', 'body_B', 'sponsored_A',
#        'sponsored_B', 'type1_A', 'type1_B', 'subtype1_A', 'subtype1_B',
#        'type2_A', 'type2_B', 'subtype2_A', 'subtype2_B', 'filename',
#        'embedded_text', 'video_file_path', 'audio_class',
#        'whisper_transcription', 'HITId_B.1', 'HITId_B.2', 'AssignmentId_B.1',
#        'AssignmentId_B.2', 'WorkerId_B.1', 'WorkerId_B.2', 'SubmitTime_B.1',
#        'SubmitTime_B.2', 'note_B.1', 'note_B.2', 'severity_B.1',
#        'severity_B.2', 'body_B.1', 'body_B.2', 'sponsored_B.1',
#        'sponsored_B.2', 'type1_B.1', 'type1_B.2', 'subtype1_B.1',
#        'subtype1_B.2', 'type2_B.1', 'type2_B.2', 'subtype2_B.1',
#        'subtype2_B.2'],
#       dtype='object')

# %%
filter_all_df = all_df[["video_id", "video_url_tiktok", "video_description", "type", "subtype", "severity", "embedded_text", "whisper_transcription"]]

# %%
filter_all_df
# Out:
#                  video_id                                   video_url_tiktok  \
# 0     6931782132905905414  https://www.tiktok.com/@konlan_james/video/693...
# 1     6931782132905905414  https://www.tiktok.com/@konlan_james/video/693...
# 2     6970472829808643334  https://www.tiktok.com/@justfitjustice/video/6...
# 3     7201940833388612870  https://www.tiktok.com/@dalladoir/video/720194...
# 4     7211496229694377258  https://www.tiktok.com/@sexedtok/video/7211496...
# ...                   ...                                                ...
# 2205  7500753537287163166  https://www.tiktok.com/@saucymcstinkypants/vid...
# 2206  7503390720049433861  https://www.tiktok.com/@nabberlifts/video/7503...
# 2207  7513211645707963678  https://www.tiktok.com/@kelsey.poulter/video/7...
# 2208  7514416059340950827  https://www.tiktok.com/@joseph.em1/video/75144...
# 2209  7514492600305405214  https://www.tiktok.com/@365dx/video/7514492600...
#
#                                       video_description  \
# 0     Check out @transcendhrt and my YouTube for mor...
# 1     Check out @transcendhrt and my YouTube for mor...
# 2                Comment if you agree #xyzbca #yolkclub
# 3     #gymtok #bodybuilding #emotional #sad #fitness...
# 4     Replying to @mark_oconnor87 unfortunately, man...
# ...                                                 ...
# 2205                lack of perfection makes you human
# 2206  Stronger together  Tag them! #gym #gymtok #gym...
# 2207             What to eat before and after practice!
# 2208         All they do #fyp #gymhumor #GymTok #viral
# 2209            like thats crazy behavior #fyp #gymtok
#
#                              type             subtype  severity  \
# 0                Supplement Abuse            Hormones      2.00
# 1                Supplement Abuse     Hormone Therapy      4.00
# 2     Relationship to Masculinity                 NaN      3.50
# 3        Relationship to Exercise  Excessive Exercise      2.00
# 4                Supplement Abuse            Hormones      2.00
# ...                           ...                 ...       ...
# 2205         Relationship to Food                 NaN      3.00
# 2206     Relationship to Exercise    Toxic Motivation      1.00
# 2207         Relationship to Food    Rigid Food Rules      1.50
# 2208     Relationship to Exercise  Excessive Exercise      1.25
# 2209     Relationship to Exercise    Toxic Motivation      2.50
#
#                                           embedded_text  \
# 0     TH\nWHAT ARE THE SIDE\nEFFECTS OF BEING ON\nTR...
# 1     WHAT ARE THE SIDE\nEFFECTS OF BEING ON\nTRT AT...
# 2     I'm not interested in drama\nover a stupid pro...
# 3                        how 40kg moves\nHow 45kg moves
# 4     Reply to mark_oconnor87's\ncomment\nAt what po...
# ...                                                 ...
# 2205  one meal led to a week\nlong binge & 10lbs gai...
# 2206  Entering the gym alone vs.\nEntering the gym w...
# 2207  WHAT TO EAT BEFORE\nAND AFTER PRACTICE\nHERE'S...
# 2208  mfs will go to the gym to\nONLY post on their ...
# 2209  people argue over politics but\nthe only peopl...
#
#                                   whisper_transcription
# 0     What are the side effects I'm getting from bei...
# 1     What are the side effects I'm getting from bei...
# 2                                                   NaN
# 3                                                   NaN
# 4     why are so many physicians reluctant either to...
# ...                                                 ...
# 2205                                                NaN
# 2206                                                NaN
# 2207  exactly what I needed to eat before and after ...
# 2208                                                NaN
# 2209                                                NaN
#
# [2210 rows x 8 columns]
